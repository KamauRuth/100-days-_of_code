# %% [markdown]
# <a href="https://colab.research.google.com/github/KamauRuth/100-days-_of_code/blob/main/house_prices_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div style="text-align: left; background-color:#0D1C5A; font-family:newtimeroman; color:#F1F40D; padding: 12px; line-height:1.25;border-radius:1px; margin-bottom: 0em; text-align: center; font-size: 40px;border-style: solid;border-color: dark green;"> 🏠 House Prices Predictions 🏠
#     <br>
#     〽️ Preprocessing + EDA + Modelling🚀 </div>
#
# <h3 style="text-align: center;font-family: Verdana; font-size: 30px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: #0A3399; background-color: #ffffff;"><b>Advanced</b> Regression<b> Techniques</b></h3>
#
# <h5 style="text-align: center; font-family: Verdana; font-size: 12px; font-style: normal; font-weight: bold; text-decoration: None; text-transform: none; letter-spacing: 1px; color: #034914; background-color: #ffffff;">CREATED BY: NGUYEN THI CAM LAI</h5>
#
# <br>
# <p style="text-align: center;">
# <img src="https://raw.githubusercontent.com/ntclai/PictureForMyProject/main/-18798-2048x1070-0.jpg" style='width: 700px; height: 650px;'>
# </p>

# %% [markdown]
# <a id="top"></a>
# # <p style="padding:10px;background-color:#0D1C5A;margin:0;color:#F1F40D;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Table Of Contents</p>
#
# <div style="background-color:aliceblue; padding:30px; font-size:15px;color:#034914">
#
# * [1. Introduction](#1)
# * [2. Import libraries](#2)
# * [3. Preprocess and Visualize data](#3)
#     - [Overall](#3.0)
#     - [Columns 1 - 16](#3.1)
#     - [Columns 17 - 32](#3.2)
#     - [Columns 33 - 48](#3.3)
#     - [Columns 49 - 64](#3.4)
#     - [Columns 65 - 80](#3.5)
#     - [Pineline](#3.6)
# * [4. Run Machine Learning model](#4)
#     - [4.1 Evaluation function](#4.1)
#     - [4.2 List of machine learning model](#4.2)
#     - [4.3 Train model and evaluate](#4.3)
#     - [4.4 Predict on test data](#4.4)
# * [5. Conclusion and submission](#5)
#     - [5.1 Conclusion](#5.1)
#     - [5.2 Submission](#5.2)
# * [6. Author Message](#6)

# %% [markdown]
# <a id="1"></a>
# # <p style="padding:10px;background-color:#0D1C5A;margin:0;color:#F1F40D;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Introduction </p>

# %% [markdown]
# <div style="border-radius:10px;border:#034914 solid;padding: 15px;background-color:aliceblue;font-size:110%;text-align:left">
#
# <strong>Subject:</strong> Kaggle Competition - House Prices - Advanced regression techniques
# <br>
# <strong>Summary:</strong>
# - This is a contest held on the Kaggle website, the goal of the contest is to find machine learning models to predict house prices based on the properties provided. The model will be ranked higher if the error between prediction and reality is smaller.
# <br>
#
# <strong>Main presentation items:</strong> <br>
# - Data overview, data analysis and preprocessing.<br>
# - Build data preprocessing model.<br>
# - Select <b>regression models</b> to make predictions: Linear Regression, Decision Tree Regression, Ridge Regression, Lasso Lars, SVR, Gradient Boosting, Random Forest Regression, Logistic Regression, Bayesian Ridge.<br>
# - Experiment: train the models on the provided data, calculate the error of the models and make predictions on Kaggle's test set.
#
# <p style="text-align: center;">
# <img src="https://raw.githubusercontent.com/ntclai/PictureForMyProject/main/cover_2022.jpeg" style='width: 500px; height: 300px;'>
# </p>
# </div>

# %% [markdown]
# <center> <a href="#top" role="button" aria-pressed="true" >⬆️Back to Table of Contents ⬆️</a>

# %% [markdown]
# <a id="2"></a>
# # <p style="padding:10px;background-color:#0D1C5A;margin:0;color:#F1F40D;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Importing Libraries</p>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score,mean_squared_log_error
from sklearn.preprocessing import OrdinalEncoder,OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn import set_config
from sklearn.model_selection import train_test_split

from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression, LassoLars, SGDRegressor, Ridge, LogisticRegression, BayesianRidge
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor

set_config(display='diagram')

# %% [markdown]
# <center> <a href="#top" role="button" aria-pressed="true" >⬆️Back to Table of Contents ⬆️</a>

# %% [markdown]
# <a id="3"></a>
# # <p style="padding:10px;background-color:#0D1C5A;margin:0;color:#F1F40D;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Preprocess and Visualize data</p>

# %% [markdown]
# <a id="3.0"></a>
# <center> <span style="font-family:newtimeroman"> <span style="padding:5px;display:fill;border-radius:20px 50px;background-color:#470437;font-size:200%;font-weight: 500;color:white;overflow:hidden;">ㅤOverallㅤ</span>
# <p style="text-align: center;">
# <img src="https://raw.githubusercontent.com/ntclai/PictureForMyProject/main/chart.png" style='width: 150px; height: 150px;'>
# </p>

# %%
data_df = pd.read_csv("/train.csv")
data_df.head().style.set_properties(**{'background-color': 'aliceblue' ,'color':'black','border-color': '#8b8c8c'})
# Out:
# <style type="text/css">
# #T_29de6_row0_col0, #T_29de6_row0_col1, #T_29de6_row0_col2, #T_29de6_row0_col3, #T_29de6_row0_col4, #T_29de6_row0_col5, #T_29de6_row0_col6, #T_29de6_row0_col7, #T_29de6_row0_col8, #T_29de6_row0_col9, #T_29de6_row0_col10, #T_29de6_row0_col11, #T_29de6_row0_col12, #T_29de6_row0_col13, #T_29de6_row0_col14, #T_29de6_row0_col15, #T_29de6_row0_col16, #T_29de6_row0_col17, #T_29de6_row0_col18, #T_29de6_row0_col19, #T_29de6_row0_col20, #T_29de6_row0_col21, #T_29de6_row0_col22, #T_29de6_row0_col23, #T_29de6_row0_col24, #T_29de6_row0_col25, #T_29de6_row0_col26, #T_29de6_row0_col27, #T_29de6_row0_col28, #T_29de6_row0_col29, #T_29de6_row0_col30, #T_29de6_row0_col31, #T_29de6_row0_col32, #T_29de6_row0_col33, #T_29de6_row0_col34, #T_29de6_row0_col35, #T_29de6_row0_col36, #T_29de6_row0_col37, #T_29de6_row0_col38, #T_29de6_row0_col39, #T_29de6_row0_col40, #T_29de6_row0_col41, #T_29de6_row0_col42, #T_29de6_row0_col43, #T_29de6_row0_col44, #T_29de6_row0_col45, #T_29de6_row0_col46, #T_29de6_row0_col47, #T_29de6_row0_col48, #T_29de6_row0_col49, #T_29de6_row0_col50, #T_29de6_row0_col51, #T_29de6_row0_col52, #T_29de6_row0_col53, #T_29de6_row0_col54, #T_29de6_row0_col55, #T_29de6_row0_col56, #T_29de6_row0_col57, #T_29de6_row0_col58, #T_29de6_row0_col59, #T_29de6_row0_col60, #T_29de6_row0_col61, #T_29de6_row0_col62, #T_29de6_row0_col63, #T_29de6_row0_col64, #T_29de6_row0_col65, #T_29de6_row0_col66, #T_29de6_row0_col67, #T_29de6_row0_col68, #T_29de6_row0_col69, #T_29de6_row0_col70, #T_29de6_row0_col71, #T_29de6_row0_col72, #T_29de6_row0_col73, #T_29de6_row0_col74, #T_29de6_row0_col75, #T_29de6_row0_col76, #T_29de6_row0_col77, #T_29de6_row0_col78, #T_29de6_row0_col79, #T_29de6_row0_col80, #T_29de6_row1_col0, #T_29de6_row1_col1, #T_29de6_row1_col2, #T_29de6_row1_col3, #T_29de6_row1_col4, #T_29de6_row1_col5, #T_29de6_row1_col6, #T_29de6_row1_col7, #T_29de6_row1_col8, #T_29de6_row1_col9, #T_29de6_row1_col10, #T_29de6_row1_col11, #T_29de6_row1_col12, #T_29de6_row1_col13, #T_29de6_row1_col14, #T_29de6_row1_col15, #T_29de6_row1_col16, #T_29de6_row1_col17, #T_29de6_row1_col18, #T_29de6_row1_col19, #T_29de6_row1_col20, #T_29de6_row1_col21, #T_29de6_row1_col22, #T_29de6_row1_col23, #T_29de6_row1_col24, #T_29de6_row1_col25, #T_29de6_row1_col26, #T_29de6_row1_col27, #T_29de6_row1_col28, #T_29de6_row1_col29, #T_29de6_row1_col30, #T_29de6_row1_col31, #T_29de6_row1_col32, #T_29de6_row1_col33, #T_29de6_row1_col34, #T_29de6_row1_col35, #T_29de6_row1_col36, #T_29de6_row1_col37, #T_29de6_row1_col38, #T_29de6_row1_col39, #T_29de6_row1_col40, #T_29de6_row1_col41, #T_29de6_row1_col42, #T_29de6_row1_col43, #T_29de6_row1_col44, #T_29de6_row1_col45, #T_29de6_row1_col46, #T_29de6_row1_col47, #T_29de6_row1_col48, #T_29de6_row1_col49, #T_29de6_row1_col50, #T_29de6_row1_col51, #T_29de6_row1_col52, #T_29de6_row1_col53, #T_29de6_row1_col54, #T_29de6_row1_col55, #T_29de6_row1_col56, #T_29de6_row1_col57, #T_29de6_row1_col58, #T_29de6_row1_col59, #T_29de6_row1_col60, #T_29de6_row1_col61, #T_29de6_row1_col62, #T_29de6_row1_col63, #T_29de6_row1_col64, #T_29de6_row1_col65, #T_29de6_row1_col66, #T_29de6_row1_col67, #T_29de6_row1_col68, #T_29de6_row1_col69, #T_29de6_row1_col70, #T_29de6_row1_col71, #T_29de6_row1_col72, #T_29de6_row1_col73, #T_29de6_row1_col74, #T_29de6_row1_col75, #T_29de6_row1_col76, #T_29de6_row1_col77, #T_29de6_row1_col78, #T_29de6_row1_col79, #T_29de6_row1_col80, #T_29de6_row2_col0, #T_29de6_row2_col1, #T_29de6_row2_col2, #T_29de6_row2_col3, #T_29de6_row2_col4, #T_29de6_row2_col5, #T_29de6_row2_col6, #T_29de6_row2_col7, #T_29de6_row2_col8, #T_29de6_row2_col9, #T_29de6_row2_col10, #T_29de6_row2_col11, #T_29de6_row2_col12, #T_29de6_row2_col13, #T_29de6_row2_col14, #T_29de6_row2_col15, #T_29de6_row2_col16, #T_29de6_row2_col17, #T_29de6_row2_col18, #T_29de6_row2_col19, #T_29de6_row2_col20, #T_29de6_row2_col21, #T_29de6_row2_col22, #T_29de6_row2_col23, #T_29de6_row2_col24, #T_29de6_row2_col25, #T_29de6_row2_col26, #T_29de6_row2_col27, #T_29de6_row2_col28, #T_29de6_row2_col29 ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
sns.displot(x=data_df['SalePrice'],kde=True,height=7,aspect=1.5);

# %%
corrmat = data_df.corr()
plt.subplots(figsize=(12,12))
sns.heatmap(corrmat, vmax=0.9, square=True);

# %%
corrmat['SalePrice'].plot(kind='bar',figsize=(15,7),title='Correlation between SalePrice and other attributes');

# %% [markdown]
# <center> <a href="#top" role="button" aria-pressed="true" >⬆️Back to Table of Contents ⬆️</a>

# %% [markdown]
# <a id="3.1"></a>
# <center> <span style="font-family:newtimeroman"> <span style="padding:5px;display:fill;border-radius:20px 50px;background-color:#470437;font-size:200%;font-weight: 500;color:white;overflow:hidden;">ㅤColumns 1 - 16ㅤ</span>
# <p style="text-align: center;">
# <img src="https://raw.githubusercontent.com/ntclai/PictureForMyProject/main/chart.png" style='width: 150px; height: 150px;'>
# </p>

# %% [markdown]
# <h5 style="text-align: left; font-family: Verdana; font-size: 20px; font-style: normal; font-weight: bold; text-decoration: None; text-transform: none; letter-spacing: 1px; color: #034914; background-color: #ffffff;">Preprocess</h5>

# %%
sns.pairplot(data_df[['LotArea','LotFrontage','MSSubClass']],diag_kind="kde");

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5), sharey=True)
sns.scatterplot(ax=axes[0], x=data_df['LotArea'], y=data_df['SalePrice'])
axes[0].set_title('LotArea')
sns.scatterplot(ax=axes[1], x=data_df['LotFrontage'], y=data_df['SalePrice'])
axes[1].set_title('LotFrontage')
sns.scatterplot(ax=axes[2], x=data_df['MSSubClass'], y=data_df['SalePrice'])
axes[2].set_title('MSSubClass');

# %% [markdown]
# We see that all three factors above have almost no influence on the selling price

# %%
modeImputer = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
meanImputer = SimpleImputer(missing_values=np.nan, strategy='mean')
noneImputer = SimpleImputer(fill_value='None',strategy='constant')

# %% [markdown]
# With the `LotFrontage` column, we will fill in the mean value for the `nan` positions.

# %%
meanImputer.fit(data_df.loc[:,'LotFrontage'].values.reshape(-1, 1))
data_df.loc[:,'LotFrontage']=meanImputer.transform(data_df.loc[:,'LotFrontage'].values.reshape(-1, 1))

# %% [markdown]
# For the `Alley` column, according to the description from the description file, the value `nan` means there is no input, so we will enter `None`.

# %%
noneImputer.fit(data_df.loc[:,'Alley'].values.reshape(-1, 1))
data_df.loc[:,'Alley']=noneImputer.transform(data_df.loc[:,'Alley'].values.reshape(-1, 1))

# %% [markdown]
# <center> <a href="#top" role="button" aria-pressed="true" >⬆️Back to Table of Contents ⬆️</a>

# %% [markdown]
# <a id="3.2"></a>
# <center> <span style="font-family:newtimeroman"> <span style="padding:5px;display:fill;border-radius:20px 50px;background-color:#470437;font-size:200%;font-weight: 500;color:white;overflow:hidden;">ㅤColumns 17 - 32ㅤ</span>
# <p style="text-align: center;">
# <img src="https://raw.githubusercontent.com/ntclai/PictureForMyProject/main/chart.png" style='width: 150px; height: 150px;'>
# </p>

# %% [markdown]
# <h5 style="text-align: left; font-family: Verdana; font-size: 20px; font-style: normal; font-weight: bold; text-decoration: None; text-transform: none; letter-spacing: 1px; color: #034914; background-color: #ffffff;">Preprocess</h5>

# %%
col17_32 = data_df.columns[17:33].to_list()

# %%
data_df[col17_32].isnull().sum()
# Out:
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       8
# MasVnrArea       8
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual        37
# BsmtCond        37
# BsmtExposure    38
# dtype: int64

# %%
data_df["MasVnrType"].value_counts()
# Out:
# None       864
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: MasVnrType, dtype: int64

# %%
data_df[data_df['MasVnrArea'].isnull()].index
# Out:
# Int64Index([234, 529, 650, 936, 973, 977, 1243, 1278], dtype='int64')

# %%
data_df[data_df['MasVnrType'].isnull()].index
# Out:
# Int64Index([234, 529, 650, 936, 973, 977, 1243, 1278], dtype='int64')

# %% [markdown]
# If you fill in `mode`, `MasVnrType` will be entered as `None`.

# %% [markdown]
# As we can see the column `BsmtQual` is missing 37 values. We check the description file and see that these columns are the height of the basement. Missing columns mean no basement. <br />
# Columns `MasVnrArea` and `MasVnrType` are missing 8 values. These two columns are related, namely `MasVnrType` and `MasVnrArea`.
# We will proceed to fill in the missing rows with `None` and in the column `MasVnrArea` we will fill in the missing column with 0.

# %%
data_df['BsmtQual'].fillna("None",inplace=True)
data_df['MasVnrType'].fillna('None',inplace=True)
data_df['MasVnrArea'].fillna(0,inplace=True)

# %% [markdown]
# <h5 style="text-align: left; font-family: Verdana; font-size: 20px; font-style: normal; font-weight: bold; text-decoration: None; text-transform: none; letter-spacing: 1px; color: #034914; background-color: #ffffff;">Visualize</h5>

# %%
data_corr = data_df[col17_32].corr()
plt.figure(figsize=(15,7))
sns.heatmap(data_corr,annot=True);

# %% [markdown]
# The correlation between `RoofStyle` and `YearBuilt`

# %%
data_df.plot.scatter(x='YearBuilt',y='RoofStyle',figsize=(15,7));

# %% [markdown]
# <center> <a href="#top" role="button" aria-pressed="true" >⬆️Back to Table of Contents ⬆️</a>

# %% [markdown]
# <a id="3.3"></a>
# <center> <span style="font-family:newtimeroman"> <span style="padding:5px;display:fill;border-radius:20px 50px;background-color:#470437;font-size:200%;font-weight: 500;color:white;overflow:hidden;">ㅤColumns 33 - 48ㅤ</span>
# <p style="text-align: center;">
# <img src="https://raw.githubusercontent.com/ntclai/PictureForMyProject/main/chart.png" style='width: 150px; height: 150px;'>
# </p>

# %% [markdown]
# <h5 style="text-align: left; font-family: Verdana; font-size: 20px; font-style: normal; font-weight: bold; text-decoration: None; text-transform: none; letter-spacing: 1px; color: #034914; background-color: #ffffff;">Preprocess</h5>

# %%
col33_48 = data_df.columns[33:49]

# %% [markdown]
# Count the `NaN` value of each column

# %%
data_df[col33_48].isnull().sum()

# %% [markdown]
# We see that there are 3 columns with missing values ​​(NaN) namely `BsmtFinType1`, `BsmtFinType2`, `Electrical`.
# - As described in the file `data_description.txt`, the columns `BsmtFinType1` and `BsmtFinType2` carry the value `NaN` when there is no basement, we will fill these `NaN` values ​​with `None`.
# - As for the `Electrical` column, the description in the file `data_description.txt` does not specify when the value `NaN` is, but there is only one line with the value `Nan` in this column, so we will remove it. this line.

# %% [markdown]
# Fill the value `NaN` in columns `BsmtFinType1` and `BsmtFinType2` to `None`

# %%
data_df['BsmtFinType1'].fillna('None',inplace=True)
data_df['BsmtFinType2'].fillna('None',inplace=True)

# %% [markdown]
# Drop row with value `NaN` at column `Electrical`

# %%
data_df = data_df[data_df['Electrical'].isnull() != True]

# %% [markdown]
# Recount `NaN` value of each column after fill and drop

# %%
data_df[col33_48].isnull().sum()
# Out:
# BsmtFinType1    0
# BsmtFinSF1      0
# BsmtFinType2    0
# BsmtFinSF2      0
# BsmtUnfSF       0
# TotalBsmtSF     0
# Heating         0
# HeatingQC       0
# CentralAir      0
# Electrical      1
# 1stFlrSF        0
# 2ndFlrSF        0
# LowQualFinSF    0
# GrLivArea       0
# BsmtFullBath    0
# BsmtHalfBath    0
# dtype: int64

# %% [markdown]
# Thus, the `train set` has no missing values ​​in these columns.

# %% [markdown]
# <h5 style="text-align: left; font-family: Verdana; font-size: 20px; font-style: normal; font-weight: bold; text-decoration: None; text-transform: none; letter-spacing: 1px; color: #034914; background-color: #ffffff;">Visualize</h5>

# %% [markdown]
# The correlation between `GrLivArea` and `SalePrice`

# %%
data_df[['GrLivArea','SalePrice']].plot(kind='scatter',x='GrLivArea',y='SalePrice',figsize=(15,7));

# %% [markdown]
# The correlation between `1stFlrSF` and `2ndFlrSF`

# %%
data_df.plot.scatter(x='1stFlrSF',y='2ndFlrSF',figsize=(15,7));

# %%
sns.pairplot(data_df[['1stFlrSF','2ndFlrSF','SalePrice']],diag_kind="kde",height=3);

# %% [markdown]
# <center> <a href="#top" role="button" aria-pressed="true" >⬆️Back to Table of Contents ⬆️</a>

# %% [markdown]
# <a id="3.4"></a>
# <center> <span style="font-family:newtimeroman"> <span style="padding:5px;display:fill;border-radius:20px 50px;background-color:#470437;font-size:200%;font-weight: 500;color:white;overflow:hidden;">ㅤColumns 49 - 64ㅤ</span>
# <p style="text-align: center;">
# <img src="https://raw.githubusercontent.com/ntclai/PictureForMyProject/main/chart.png" style='width: 150px; height: 150px;'>
# </p>

# %% [markdown]
# <h5 style="text-align: left; font-family: Verdana; font-size: 20px; font-style: normal; font-weight: bold; text-decoration: None; text-transform: none; letter-spacing: 1px; color: #034914; background-color: #ffffff;">Preprocess</h5>

# %%
col49_64 = data_df.columns[49:65]

# %%
data_df[col49_64].isna().sum()
# Out:
# FullBath          0
# HalfBath          0
# BedroomAbvGr      0
# KitchenAbvGr      0
# KitchenQual       0
# TotRmsAbvGrd      0
# Functional        0
# Fireplaces        0
# FireplaceQu     690
# GarageType       81
# GarageYrBlt      81
# GarageFinish     81
# GarageCars        0
# GarageArea        0
# GarageQual       81
# GarageCond       81
# dtype: int64

# %% [markdown]
# We see the columns containing `nan` values ​​are `FireplaceQ`, `GarageType`, `GarageYrBlt`, `GarageFinish`, `GarageQual`, `GarageCond`. We will enter `None` in the columns `FireplaceQu, GarageType, GarageFinish, GarageQual, GarageCond` and enter `mean` in the column `GarageYrBlt`

# %%
noneImputer.fit(data_df.loc[:,['FireplaceQu','GarageType','GarageFinish','GarageQual','GarageCond']].values)
data_df.loc[:,['FireplaceQu','GarageType','GarageFinish','GarageQual','GarageCond']]=\
            noneImputer.transform(data_df.loc[:,['FireplaceQu','GarageType','GarageFinish','GarageQual','GarageCond']].values)

meanImputer.fit(data_df.loc[:,'GarageYrBlt'].values.reshape(-1, 1))
data_df.loc[:,'GarageYrBlt']=meanImputer.transform(data_df.loc[:,'GarageYrBlt'].values.reshape(-1, 1))

# %% [markdown]
# <h5 style="text-align: left; font-family: Verdana; font-size: 20px; font-style: normal; font-weight: bold; text-decoration: None; text-transform: none; letter-spacing: 1px; color: #034914; background-color: #ffffff;">Visualize</h5>

# %%
buu_corr = data_df[col49_64].corr()
plt.figure(figsize=(15,7))
sns.heatmap(buu_corr,annot=True);

# %% [markdown]
# The correlation between `GarageCars` and `GarageArea`

# %%
data_df[col49_64].plot.scatter(x='GarageArea',y='GarageCars',figsize=(15,7));

# %%
var = 'GarageCars'
data = pd.concat([data_df['SalePrice'], data_df[var]], axis=1)
f, ax = plt.subplots(figsize=(15, 7))
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);

# %% [markdown]
# <center> <a href="#top" role="button" aria-pressed="true" >⬆️Back to Table of Contents ⬆️</a>

# %% [markdown]
# <a id="3.5"></a>
# <center> <span style="font-family:newtimeroman"> <span style="padding:5px;display:fill;border-radius:20px 50px;background-color:#470437;font-size:200%;font-weight: 500;color:white;overflow:hidden;">ㅤColumns 65 - 80ㅤ</span>
# <p style="text-align: center;">
# <img src="https://raw.githubusercontent.com/ntclai/PictureForMyProject/main/chart.png" style='width: 150px; height: 150px;'>
# </p>

# %% [markdown]
# <h5 style="text-align: left; font-family: Verdana; font-size: 20px; font-style: normal; font-weight: bold; text-decoration: None; text-transform: none; letter-spacing: 1px; color: #034914; background-color: #ffffff;">Preprocess</h5>

# %%
col65_81=data_df.columns[65:81].tolist()

# %%
data_df[col65_81].isnull().sum()

# %% [markdown]
# - There are 3 columns missing, which are:
#
#     - `PoolQC`(pool quality) is missing 1452 values.
#
#     - `Fence`(fence quality) is missing 1178 values.
#
#     - `MiscFeature`(miscellaneous item) is missing 1405 values.

# %% [markdown]
# We will proceed to fill in the missing values ​​with `None`.

# %%
data_df.loc[:,'PoolQC'].fillna("None",inplace=True)
data_df.loc[:,'Fence'].fillna("None",inplace=True)
data_df.loc[:,'MiscFeature'].fillna("None",inplace=True)

# %%
data_df[col65_81].isnull().sum()
# Out:
# PavedDrive       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# PoolQC           0
# Fence            0
# MiscFeature      0
# MiscVal          0
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# dtype: int64

# %% [markdown]
# The columns no longer have missing values.

# %% [markdown]
# <h5 style="text-align: left; font-family: Verdana; font-size: 20px; font-style: normal; font-weight: bold; text-decoration: None; text-transform: none; letter-spacing: 1px; color: #034914; background-color: #ffffff;">Visualize</h5>

# %%
sns.pairplot(data_df[['OpenPorchSF','EnclosedPorch','3SsnPorch','ScreenPorch','SalePrice']],diag_kind="kde",height=2);

# %% [markdown]
# The correlation between `GarageCond` and `YrSold`

# %%
datadf=data_df.loc[:,["GarageCond","YrSold"]]
datadf
# Out:
#      GarageCond  YrSold
# 0            TA    2008
# 1            TA    2007
# 2            TA    2008
# 3            TA    2006
# 4            TA    2008
# ...         ...     ...
# 1455         TA    2007
# 1456         TA    2010
# 1457         TA    2010
# 1458         TA    2010
# 1459         TA    2008
#
# [1460 rows x 2 columns]

# %%
datadf["GarageCond"].value_counts()
# Out:
# TA      1326
# None      81
# Fa        35
# Gd         9
# Po         7
# Ex         2
# Name: GarageCond, dtype: int64

# %% [markdown]
# As we can see, the TA conditional garage is sold the most: 1326, far ahead of the rest.

# %%
datadf=datadf[datadf["GarageCond"]=='TA']
datadf
# Out:
#      GarageCond  YrSold
# 0            TA    2008
# 1            TA    2007
# 2            TA    2008
# 3            TA    2006
# 4            TA    2008
# ...         ...     ...
# 1455         TA    2007
# 1456         TA    2010
# 1457         TA    2010
# 1458         TA    2010
# 1459         TA    2008
#
# [1326 rows x 2 columns]

# %%
dataVisua=datadf["YrSold"].value_counts()
dataVisua=dataVisua.sort_index()
dataVisua.plot.bar(xlabel="YearSold",ylabel="NumSold",figsize=(15,7));

# %% [markdown]
# The number of sales from 2006 to 2009 did not differ much, but in 2010 it decreased significantly. It is likely that in the future, buyers will pay more attention to the condition of the garage instead of buying the common type as before.

# %% [markdown]
# <center> <a href="#top" role="button" aria-pressed="true" >⬆️Back to Table of Contents ⬆️</a>

# %% [markdown]
# <a id="3.6"></a>
# <center> <span style="font-family:newtimeroman"> <span style="padding:5px;display:fill;border-radius:20px 50px;background-color:#470437;font-size:200%;font-weight: 500;color:white;overflow:hidden;">ㅤPipelineㅤ</span>
# <p style="text-align: center;">
# <img src="https://raw.githubusercontent.com/ntclai/PictureForMyProject/main/1190961.png" style='width: 150px; height: 150px;'>
# </p>

# %% [markdown]
# <h5 style="text-align: left; font-family: Verdana; font-size: 20px; font-style: normal; font-weight: bold; text-decoration: None; text-transform: none; letter-spacing: 1px; color: #034914; background-color: #ffffff;">Read dataset</h5>

# %%
data_df = pd.read_csv("/train.csv")
data_df.head().style.set_properties(**{'background-color': 'aliceblue' ,'color':'black','border-color': '#8b8c8c'})
# Out:
# <style type="text/css">
# #T_f2311_row0_col0, #T_f2311_row0_col1, #T_f2311_row0_col2, #T_f2311_row0_col3, #T_f2311_row0_col4, #T_f2311_row0_col5, #T_f2311_row0_col6, #T_f2311_row0_col7, #T_f2311_row0_col8, #T_f2311_row0_col9, #T_f2311_row0_col10, #T_f2311_row0_col11, #T_f2311_row0_col12, #T_f2311_row0_col13, #T_f2311_row0_col14, #T_f2311_row0_col15, #T_f2311_row0_col16, #T_f2311_row0_col17, #T_f2311_row0_col18, #T_f2311_row0_col19, #T_f2311_row0_col20, #T_f2311_row0_col21, #T_f2311_row0_col22, #T_f2311_row0_col23, #T_f2311_row0_col24, #T_f2311_row0_col25, #T_f2311_row0_col26, #T_f2311_row0_col27, #T_f2311_row0_col28, #T_f2311_row0_col29, #T_f2311_row0_col30, #T_f2311_row0_col31, #T_f2311_row0_col32, #T_f2311_row0_col33, #T_f2311_row0_col34, #T_f2311_row0_col35, #T_f2311_row0_col36, #T_f2311_row0_col37, #T_f2311_row0_col38, #T_f2311_row0_col39, #T_f2311_row0_col40, #T_f2311_row0_col41, #T_f2311_row0_col42, #T_f2311_row0_col43, #T_f2311_row0_col44, #T_f2311_row0_col45, #T_f2311_row0_col46, #T_f2311_row0_col47, #T_f2311_row0_col48, #T_f2311_row0_col49, #T_f2311_row0_col50, #T_f2311_row0_col51, #T_f2311_row0_col52, #T_f2311_row0_col53, #T_f2311_row0_col54, #T_f2311_row0_col55, #T_f2311_row0_col56, #T_f2311_row0_col57, #T_f2311_row0_col58, #T_f2311_row0_col59, #T_f2311_row0_col60, #T_f2311_row0_col61, #T_f2311_row0_col62, #T_f2311_row0_col63, #T_f2311_row0_col64, #T_f2311_row0_col65, #T_f2311_row0_col66, #T_f2311_row0_col67, #T_f2311_row0_col68, #T_f2311_row0_col69, #T_f2311_row0_col70, #T_f2311_row0_col71, #T_f2311_row0_col72, #T_f2311_row0_col73, #T_f2311_row0_col74, #T_f2311_row0_col75, #T_f2311_row0_col76, #T_f2311_row0_col77, #T_f2311_row0_col78, #T_f2311_row0_col79, #T_f2311_row0_col80, #T_f2311_row1_col0, #T_f2311_row1_col1, #T_f2311_row1_col2, #T_f2311_row1_col3, #T_f2311_row1_col4, #T_f2311_row1_col5, #T_f2311_row1_col6, #T_f2311_row1_col7, #T_f2311_row1_col8, #T_f2311_row1_col9, #T_f2311_row1_col10, #T_f2311_row1_col11, #T_f2311_row1_col12, #T_f2311_row1_col13, #T_f2311_row1_col14, #T_f2311_row1_col15, #T_f2311_row1_col16, #T_f2311_row1_col17, #T_f2311_row1_col18, #T_f2311_row1_col19, #T_f2311_row1_col20, #T_f2311_row1_col21, #T_f2311_row1_col22, #T_f2311_row1_col23, #T_f2311_row1_col24, #T_f2311_row1_col25, #T_f2311_row1_col26, #T_f2311_row1_col27, #T_f2311_row1_col28, #T_f2311_row1_col29, #T_f2311_row1_col30, #T_f2311_row1_col31, #T_f2311_row1_col32, #T_f2311_row1_col33, #T_f2311_row1_col34, #T_f2311_row1_col35, #T_f2311_row1_col36, #T_f2311_row1_col37, #T_f2311_row1_col38, #T_f2311_row1_col39, #T_f2311_row1_col40, #T_f2311_row1_col41, #T_f2311_row1_col42, #T_f2311_row1_col43, #T_f2311_row1_col44, #T_f2311_row1_col45, #T_f2311_row1_col46, #T_f2311_row1_col47, #T_f2311_row1_col48, #T_f2311_row1_col49, #T_f2311_row1_col50, #T_f2311_row1_col51, #T_f2311_row1_col52, #T_f2311_row1_col53, #T_f2311_row1_col54, #T_f2311_row1_col55, #T_f2311_row1_col56, #T_f2311_row1_col57, #T_f2311_row1_col58, #T_f2311_row1_col59, #T_f2311_row1_col60, #T_f2311_row1_col61, #T_f2311_row1_col62, #T_f2311_row1_col63, #T_f2311_row1_col64, #T_f2311_row1_col65, #T_f2311_row1_col66, #T_f2311_row1_col67, #T_f2311_row1_col68, #T_f2311_row1_col69, #T_f2311_row1_col70, #T_f2311_row1_col71, #T_f2311_row1_col72, #T_f2311_row1_col73, #T_f2311_row1_col74, #T_f2311_row1_col75, #T_f2311_row1_col76, #T_f2311_row1_col77, #T_f2311_row1_col78, #T_f2311_row1_col79, #T_f2311_row1_col80, #T_f2311_row2_col0, #T_f2311_row2_col1, #T_f2311_row2_col2, #T_f2311_row2_col3, #T_f2311_row2_col4, #T_f2311_row2_col5, #T_f2311_row2_col6, #T_f2311_row2_col7, #T_f2311_row2_col8, #T_f2311_row2_col9, #T_f2311_row2_col10, #T_f2311_row2_col11, #T_f2311_row2_col12, #T_f2311_row2_col13, #T_f2311_row2_col14, #T_f2311_row2_col15, #T_f2311_row2_col16, #T_f2311_row2_col17, #T_f2311_row2_col18, #T_f2311_row2_col19, #T_f2311_row2_col20, #T_f2311_row2_col21, #T_f2311_row2_col22, #T_f2311_row2_col23, #T_f2311_row2_col24, #T_f2311_row2_col25, #T_f2311_row2_col26, #T_f2311_row2_col27, #T_f2311_row2_col28, #T_f2311_row2_col29 ...

# %% [markdown]
# <h5 style="text-align: left; font-family: Verdana; font-size: 20px; font-style: normal; font-weight: bold; text-decoration: None; text-transform: none; letter-spacing: 1px; color: #034914; background-color: #ffffff;">Split training and validation data</h5>

# %%
y_sr = data_df["SalePrice"]
X_df = data_df.drop("SalePrice", axis=1)

# %%
train_X_df, val_X_df, train_y_sr, val_y_sr = train_test_split(X_df, y_sr, 
                                               test_size=0.2, 
                                               random_state=0)

# %% [markdown]
# <h5 style="text-align: left; font-family: Verdana; font-size: 20px; font-style: normal; font-weight: bold; text-decoration: None; text-transform: none; letter-spacing: 1px; color: #034914; background-color: #ffffff;">Create Pipeline</h5>

# %%
def GroupingColumns(df):
    categorical_cols = []
    numerical_cols = []
    for col in df.columns:
        if df[col].dtype=='object':
            categorical_cols.append(col)
        else:
            numerical_cols.append(col)
    return categorical_cols, numerical_cols

# %%
cate_cols_with_nan_defined = ['Alley','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2',
                              'FireplaceQu','GarageType','GarageFinish','GarageQual','GarageCond','PoolQC',
                             'Fence','MiscFeature']
cate_cols_considered = ['MSSubClass']
remaining_cols=[col for col in train_X_df.columns if col not in cate_cols_with_nan_defined+cate_cols_considered]
remaining_cate_cols, numerical_cols = GroupingColumns(train_X_df[remaining_cols])
cate_cols = cate_cols_with_nan_defined + cate_cols_considered + remaining_cate_cols
numerical_cols.remove('Id')

# %%
modeImputer = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
meanImputer = SimpleImputer(missing_values=np.nan, strategy='mean')
noneImputer = SimpleImputer(fill_value='None',strategy='constant')

# %%
ordinal_mappings = {
    "MSSubClass": [ 20, 30,40,45,50,60,70,75,80,85, 90,120,150,160,180,190], 
    "ExterQual": ['Po','Fa','TA','Gd','Ex'], 
    "ExterCond": ['Po','Fa','TA','Gd','Ex'],
    "LotShape": ['Reg','IR1' ,'IR2','IR3'], 
    "BsmtQual": ['None','Fa','TA','Gd','Ex'], 
    "BsmtCond": ['None','Po','Fa','TA','Gd','Ex'], 
    "BsmtExposure": ['None','No','Mn','Av','Gd'], 
    "BsmtFinType1": ['None','Unf','LwQ', 'Rec','BLQ','ALQ' , 'GLQ' ], 
    "BsmtFinType2": ['None','Unf','LwQ', 'Rec','BLQ','ALQ' , 'GLQ' ], 
    "HeatingQC": ['Po','Fa','TA','Gd','Ex'], 
    "Functional": ['Sev','Maj2','Maj1','Mod','Min2','Min1','Typ'], 
    "FireplaceQu": ['None','Po','Fa','TA','Gd','Ex'], 
    "KitchenQual": ['Fa','TA','Gd','Ex'], 
    "GarageFinish": ['None','Unf','RFn','Fin'], 
    "GarageQual": ['None','Po','Fa','TA','Gd','Ex'], 
    "GarageCond": ['None','Po','Fa','TA','Gd','Ex'], 
    "PoolQC": ['None','Fa','Gd','Ex'], 
    "Fence": ['None','MnWw','GdWo','MnPrv','GdPrv'],
}
   
ordinal_encoding_cols1 = ['MSSubClass','ExterQual','ExterCond','LotShape','HeatingQC','Functional','KitchenQual']
ordinal_encoder1 = OrdinalEncoder(categories=[ordinal_mappings[i] for i in ordinal_encoding_cols1])

ordinal_encoding_cols2 = [col for col in [*ordinal_mappings] if col not in ordinal_encoding_cols1]
ordinal_encoder2 = OrdinalEncoder(categories=[ordinal_mappings[i] for i in ordinal_encoding_cols2])

oh_encoding_cols = [col for col in cate_cols if col not in [*ordinal_mappings]]
oh_encoder = OneHotEncoder(handle_unknown='ignore',sparse=False)
mode_oh = list(set(remaining_cate_cols) & set(oh_encoding_cols))
none_oh = list(set(cate_cols_with_nan_defined) & set(oh_encoding_cols))

# %%
class columnDropperTransformer():
    def __init__(self,columns):
        self.columns=columns

    def transform(self,X,y=None):
        return X.drop(self.columns,axis=1)

    def fit(self, X, y=None):
        return self

# %%
mode_oh_pl = Pipeline([('Mode',modeImputer),('OneHotEncode',oh_encoder)])
mode_or_pl = Pipeline([('Mode',modeImputer),('OrdinalEncode',ordinal_encoder1)])
none_oh_pl = Pipeline([('None',noneImputer),('OneHotEncode',oh_encoder)])
none_or_pl = Pipeline([('None',noneImputer),('OrdinalEncode',ordinal_encoder2)])

cols_transformer = ColumnTransformer([
    ('Mean',meanImputer,numerical_cols),
    ('Mode-OHEncode',mode_oh_pl,mode_oh),
    ('Mode-OdEncode',mode_or_pl,ordinal_encoding_cols1),
    ('None-OHEncode',none_oh_pl,none_oh),
    ('None-OdEncode',none_or_pl,ordinal_encoding_cols2),
])
preprocess = Pipeline([
    ("columnDropper", columnDropperTransformer(['Id'])),
    ('ColsTransformer',cols_transformer),
    ('StdScaler',StandardScaler())
])

preprocess
# Out:
# Pipeline(steps=[('columnDropper',
#                  <__main__.columnDropperTransformer object at 0x7f4186505bb0>),
#                 ('ColsTransformer',
#                  ColumnTransformer(transformers=[('Mean', SimpleImputer(),
#                                                   ['LotFrontage', 'LotArea',
#                                                    'OverallQual', 'OverallCond',
#                                                    'YearBuilt', 'YearRemodAdd',
#                                                    'MasVnrArea', 'BsmtFinSF1',
#                                                    'BsmtFinSF2', 'BsmtUnfSF',
#                                                    'TotalBsmtSF', '1stFlrSF',
#                                                    '2ndFlrSF', 'LowQualFinSF',
#                                                    '...
#                                                                                                'Gd',
#                                                                                                'Ex'],
#                                                                                               ['None',
#                                                                                                'Unf',
#                                                                                                'RFn',
#                                                                                                'Fin'],
#                                                                                               ['None',
#                                                                                                'Po',
#                                                                                                'Fa',
#                                                                                                'TA',
#                                                                                                'Gd',
#                                                                                                'Ex'],
#                                                                                               ['None',
#                                                                                                'Po',
#                                                                                                'Fa',
#                                                                                                'TA',
#                                                                                                'Gd',
#                                                                                                'Ex'],
#                                                                                               ['None',
#                                                                                                'Fa',
#                                                                                                'Gd',
#                                                                                                'Ex'],
#                                                                                               ['None',
#                                                                                                'MnWw',
#                                                                                                'GdWo',
#                                                                                                'MnPrv',
#                                                                                                'GdPrv']]))]),
#                                                   ['BsmtQual', 'BsmtCond',
#                                                    'BsmtExposure',
#                                                    'BsmtFinType1',
#                                                    'BsmtFinType2',
#                                                    'FireplaceQu',
#                                                    'GarageFinish', 'GarageQual',
#                                                    'GarageCond', 'PoolQC',
#                                                    'Fence'])])),
#                 ('StdScaler', StandardScaler())])

# %% [markdown]
# <center> <a href="#top" role="button" aria-pressed="true" >⬆️Back to Table of Contents ⬆️</a>

# %% [markdown]
# <a id="4"></a>
# # <p style="padding:10px;background-color:#0D1C5A;margin:0;color:#F1F40D;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500"> Run Machine Learning model</p>

# %% [markdown]
# <a id="4.1"></a>
# <center> <span style="font-family:newtimeroman"> <span style="padding:5px;display:fill;border-radius:20px 50px;background-color:#470437;font-size:200%;font-weight: 500;color:white;overflow:hidden;">ㅤEvaluation functionㅤ</span>
# <p style="text-align: center;">
# <img src="https://raw.githubusercontent.com/ntclai/PictureForMyProject/main/setting.png" style='width: 150px; height: 150px;'>
# </p>

# %%
def evaluate(y_true, y_pred):
    mae = mean_absolute_error(y_true,y_pred)
    mse = mean_squared_error(y_true,y_pred)
    rsquare = r2_score(y_true,y_pred)
    rmse = mean_squared_error(y_true,y_pred,squared = False)
    try:
        rmsle = mean_squared_log_error(y_true,y_pred,squared = False)
    except:
        rmsle = np.nan
    return mae, mse, rsquare, rmse, rmsle

# %% [markdown]
# <center> <a href="#top" role="button" aria-pressed="true" >⬆️Back to Table of Contents ⬆️</a>

# %% [markdown]
# <a id="4.2"></a>
# <center> <span style="font-family:newtimeroman"> <span style="padding:5px;display:fill;border-radius:20px 50px;background-color:#470437;font-size:200%;font-weight: 500;color:white;overflow:hidden;">List of machine learning model </span>
# <p style="text-align: center;">
# <img src="https://raw.githubusercontent.com/ntclai/PictureForMyProject/main/41591_2020_1197_Figa_HTML.png" style='width: 180px; height: 100px;'>
# </p>

# %% [markdown]
# <h3 style="font-family: Verdana; font-size: 15px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: #0A3399; background-color: #ffffff;"><b>We</b> using<b> regression</b> models: </h3>
#
# > `Decision Tree Regressor` <br>
# > `Linear Regression` <br>
# > `Lasso Lars` <br>
# > `Ridge Regression` <br>
# > `SVR` <br>
# > `Random Forest Regression` <br>
# > `Logistic Regression` <br>
# > `Bayesian Ridge` <br>
# > `Gradient Boostring` <br>

# %%
model_list = {
    'decision_tree_regression':DecisionTreeRegressor(random_state = 42),
    'linear_regression':LinearRegression(),
    'lasso_lars':LassoLars(alpha=41,eps=1.38,random_state = 42,normalize=False),
    'ridge_regression':Ridge(alpha=1778,random_state=42),
    'SVR': SVR(),
    'random_forest_regression':RandomForestRegressor(n_estimators=400,random_state = 42),
    'logistic_regression':LogisticRegression(random_state = 42),
    'bayesian_ridge':BayesianRidge(),
    'gradient_boosting':GradientBoostingRegressor(random_state = 42),
}

# %% [markdown]
# <center> <a href="#top" role="button" aria-pressed="true" >⬆️Back to Table of Contents ⬆️</a>

# %% [markdown]
# <a id="4.3"></a>
# <center> <span style="font-family:newtimeroman"> <span style="padding:5px;display:fill;border-radius:20px 50px;background-color:#470437;font-size:200%;font-weight: 500;color:white;overflow:hidden;"> Train model and evaluate </span>
# <p style="text-align: center;">
# <img src="https://raw.githubusercontent.com/ntclai/PictureForMyProject/main/training.png" style='width: 150px; height: 150px;'>
# </p>

# %% [markdown]
# <h3 style="font-family: Verdana; font-size: 15px; font-style: normal; font-weight: normal; text-decoration: none; text-transform: none; letter-spacing: 2px; color: #0A3399; background-color: #ffffff;"><b>We</b> will<b> evaluate</b> the <b> models </b> by: </h3>
#
# > `MAE` <br>
# > `MSE` <br>
# > `R2 Square` <br>
# > `RMSE` <br>
# > `RMSLE` <br>

# %%
preprocessed_train_X = preprocess.fit_transform(train_X_df)
preprocessed_val_X = preprocess.transform(val_X_df)
score = dict()
for key in model_list.keys():
    model = model_list[key].fit(preprocessed_train_X,train_y_sr)
    val_y_pred = model.predict(preprocessed_val_X)
    score[key] = evaluate(val_y_sr,val_y_pred)
score_df = pd.DataFrame(score).T.round(5)
score_df.columns=['MAE','MSE','R2 Square','RMSE','RMSLE']
score_df.style.set_properties(**{'background-color': 'aliceblue' ,'color':'black','border-color': '#8b8c8c'})
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_least_angle.py:682: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 113 iterations, alpha=5.278e+02, previous alpha=5.272e+02, with an active set of 108 regressors.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# <style type="text/css">
# #T_2e759_row0_col0, #T_2e759_row0_col1, #T_2e759_row0_col2, #T_2e759_row0_col3, #T_2e759_row0_col4, #T_2e759_row1_col0, #T_2e759_row1_col1, #T_2e759_row1_col2, #T_2e759_row1_col3, #T_2e759_row1_col4, #T_2e759_row2_col0, #T_2e759_row2_col1, #T_2e759_row2_col2, #T_2e759_row2_col3, #T_2e759_row2_col4, #T_2e759_row3_col0, #T_2e759_row3_col1, #T_2e759_row3_col2, #T_2e759_row3_col3, #T_2e759_row3_col4, #T_2e759_row4_col0, #T_2e759_row4_col1, #T_2e759_row4_col2, #T_2e759_row4_col3, #T_2e759_row4_col4, #T_2e759_row5_col0, #T_2e759_row5_col1, #T_2e759_row5_col2, #T_2e759_row5_col3, #T_2e759_row5_col4, #T_2e759_row6_col0, #T_2e759_row6_col1, #T_2e759_row6_col2, #T_2e759_row6_col3, #T_2e759_row6_col4, #T_2e759_row7_col0, #T_2e759_row7_col1, #T_2e759_row7_col2, #T_2e759_row7_col3, #T_2e759_row7_col4, #T_2e759_row8_col0, #T_2e759_row8_col1, #T_2e759_row8_col2, #T_2e759_row8_col3, #T_2e759_row8_col4 {
#   background-color: aliceblue;
#   color: black;
#   border-color: #8b8c8c;
# }
# </style>
# <table id="T_2e759_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >R2 Square</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e759_level0_row0" class="row_heading level0 row0" >decision_tree_regression</th>
#       <td id="T_2e759_row0_col0" class="data row0 col0" >27938.869860</td>
#       <td id="T_2e759_row0_col1" class="data row0 col1" >2080464906.719180</td>
#       <td id="T_2e759_row0_col2" class="data row0 col2" >0.698740</td>
#       <td id="T_2e759_row0_col3" class="data row0 col3" >45612.113600</td>
#       <td id="T_2e759_row0_col4" class="data row0 col4" >0.223930</td>
#     </tr>
#     <tr>
#       <th id="T_2e759_level0_row1" class="row_heading level0 row1" >linear_regression</th>
#       <td id="T_2e759_row1_col0" class="data row1 col0" >17437182759971816.000000</td>
#       <td id="T_2e759_row1_col1" class="data row1 col1" >15030467254302262182548391956840448.000000</td>
#       <td id="T_2e759_row1_col2" class="data row1 col2" >-2176483319598297181585408.000000</td>
#       <td id="T_2e759_row1_col3" class="data row1 col3" >122598806088404736.000000</td>
#       <td id="T_2e759_row1_col4" class="data row1 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2e759_level0_row2" class="row_heading level0 row2" >lasso_lars</th>
#       <td id="T_2e759_row2_col0" class="data row2 col0" >21782.208230</td>
#       <td id="T_2e759_row2_col1" class="data row2 col1" >2615407676.622130</td>
#       <td id="T_2e759_row2_col2" class="data row2 col2" >0.621280</td>
#       <td id="T_2e759_row2_col3" class="data row2 col3" >51141.056660</td>
#       <td id="T_2e759_row2_col4" class="data row2 col4" >0.229700</td>
#     </tr>
#     <tr>
#       <th id="T_2e759_level0_row3" class="row_heading level0 row3" >ridge_regression</th>
#       <td id="T_2e759_row3_col0" class="data row3 col0" >21580.039430</td>
#       <td id="T_2e759_row3_col1" class="data row3 col1" >1962877648.182600</td>
#       <td id="T_2e759_row3_col2" class="data row3 col2" >0.715770</td>
#       <td id="T_2e759_row3_col3" class="data row3 col3" >44304.375050</td>
#       <td id="T_2e759_row3_col4" class="data row3 col4" >0.166600</td>
#     </tr>
#     <tr>
#       <th id="T_2e759_level0_row4" class="row_heading level0 row4" >SVR</th>
#       <td id="T_2e759_row4_col0" class="data row4 col0" >55532.494500</td>
#       <td id="T_2e759_row4_col1" class="data row4 col1" >7239551916.601590</td>
#       <td id="T_2e759_row4_col2" class="data row4 col2" >-0.048320</td>
#       <td id="T_2e759_row4_col3" class="data row4 col3" >85085.556450</td>
#       <td id="T_2e759_row4_col4" class="data row4 col4" >0.389780</td>
#     </tr>
#     <tr>
#       <th id="T_2e759_level0_row5" class="row_heading level0 row5" >random_forest_regression</th>
#       <td id="T_2e759_row5_col0" class="data row5 col0" >17163.993660</td>
#       <td id="T_2e759_row5_col1" class="data row5 col1" >1103978927.097100</td>
#       <td id="T_2e759_row5_col2" class="data row5 col2" >0.840140</td>
#       <td id="T_2e759_row5_col3" class="data row5 col3" >33226.178340</td>
#       <td id="T_2e759_row5_col4" class="data row5 col4" >0.139940</td>
#     </tr>
#     <tr>
#       <th id="T_2e759_level0_row6" class="row_heading level0 row6" >logistic_regression</th>
#       <td id="T_2e759_row6_col0" class="data row6 col0" >36509.188360</td>
#       <td id="T_2e759_row6_col1" class="data row6 col1" >4425206115.948630</td>
#       <td id="T_2e759_row6_col2" class="data row6 col2" >0.359210</td>
#       <td id="T_2e759_row6_col3" class="data row6 col3" >66522.222720</td>
#       <td id="T_2e759_row6_col4" class="data row6 col4" >0.277020</td>
#     </tr>
#     <tr>
#       <th id="T_2e759_level0_row7" class="row_heading level0 row7" >bayesian_ridge</th>
#       <td id="T_2e759_row7_col0" class="data row7 col0" >22629.399820</td>
#       <td id="T_2e759_row7_col1" class="data row7 col1" >2647103297.770640</td>
#       <td id="T_2e759_row7_col2" class="data row7 col2" >0.616690</td>
#       <td id="T_2e759_row7_col3" class="data row7 col3" >51450.007750</td>
#       <td id="T_2e759_row7_col4" class="data row7 col4" >0.234790</td>
#     </tr>
#     <tr>
#       <th id="T_2e759_level0_row8" class="row_heading level0 row8" >gradient_boosting</th>
#       <td id="T_2e759_row8_col0" class="data row8 col0" >16388.637240</td>
#       <td id="T_2e759_row8_col1" class="data row8 col1" >817634481.751610</td>
#       <td id="T_2e759_row8_col2" class="data row8 col2" >0.881600</td>
#       <td id="T_2e759_row8_col3" class="data row8 col3" >28594.308560</td>
#       <td id="T_2e759_row8_col4" class="data row8 col4" >0.126850</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <center> <a href="#top" role="button" aria-pressed="true" >⬆️Back to Table of Contents ⬆️</a>

# %% [markdown]
# <a id="4.4"></a>
# <center> <span style="font-family:newtimeroman"> <span style="padding:5px;display:fill;border-radius:20px 50px;background-color:#470437;font-size:200%;font-weight: 500;color:white;overflow:hidden;"> Predict on test data </span>
# <p style="text-align: center;">
# <img src="https://raw.githubusercontent.com/ntclai/PictureForMyProject/main/910373.png" style='width: 150px; height: 150px;'>
# </p>

# %%
test_X_df = pd.read_csv("/test.csv")
preprocessed_X_df = preprocess.fit_transform(X_df)
preprocessed_test_X_df = preprocess.transform(test_X_df)
for key in model_list.keys():
    model = model_list[key].fit(preprocessed_X_df,y_sr)
    test_y_sr = model.predict(preprocessed_test_X_df)
    df=pd.DataFrame({'Id':test_X_df.Id,'SalePrice':test_y_sr})
    df.to_csv('/test'+key+'.csv',index=False)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# <center> <a href="#top" role="button" aria-pressed="true" >⬆️Back to Table of Contents ⬆️</a>

# %% [markdown]
# <a id="5"></a>
# # <p style="padding:10px;background-color:#0D1C5A;margin:0;color:#F1F40D;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500"> Conclusion and submission</p>

# %% [markdown]
# <a id="5.1"></a>
# <center> <span style="font-family:newtimeroman"> <span style="padding:5px;display:fill;border-radius:20px 50px;background-color:#470437;font-size:200%;font-weight: 500;color:white;overflow:hidden;"> Conclusion </span>
# <p style="text-align: center;">
# <img src="https://raw.githubusercontent.com/ntclai/PictureForMyProject/main/conclusion.jpg" style='width: 150px; height: 150px;'>
# </p>

# %% [markdown]
# <div style="border-radius:10px;border:#034914 solid;padding: 15px;background-color:aliceblue;font-size:110%;text-align:left">
#
# <b>Summary:</b> after training the models on the provided data, the model with the best results is <b>Gradient Boosting</b> with a score of <b>0.13683</b> (using RMSLE measure and Kaggle's test data).
# </div>

# %% [markdown]
# <center> <a href="#top" role="button" aria-pressed="true" >⬆️Back to Table of Contents ⬆️</a>

# %% [markdown]
# <a id="5.2"></a>
# <center> <span style="font-family:newtimeroman"> <span style="padding:5px;display:fill;border-radius:20px 50px;background-color:#470437;font-size:200%;font-weight: 500;color:white;overflow:hidden;"> Submission </span>
# <p style="text-align: center;">
# <img src="https://raw.githubusercontent.com/ntclai/PictureForMyProject/main/5360973.png" style='width: 150px; height: 150px;'>
# </p>

# %%
submission = pd.read_csv('/testgradient_boosting.csv')
submission.to_csv("submission.csv", index = False)
submission.head(10).style.set_properties(**{'background-color': 'aliceblue' ,'color':'black','border-color': '#8b8c8c'})
# Out:
# <style type="text/css">
# #T_11e6d_row0_col0, #T_11e6d_row0_col1, #T_11e6d_row1_col0, #T_11e6d_row1_col1, #T_11e6d_row2_col0, #T_11e6d_row2_col1, #T_11e6d_row3_col0, #T_11e6d_row3_col1, #T_11e6d_row4_col0, #T_11e6d_row4_col1, #T_11e6d_row5_col0, #T_11e6d_row5_col1, #T_11e6d_row6_col0, #T_11e6d_row6_col1, #T_11e6d_row7_col0, #T_11e6d_row7_col1, #T_11e6d_row8_col0, #T_11e6d_row8_col1, #T_11e6d_row9_col0, #T_11e6d_row9_col1 {
#   background-color: aliceblue;
#   color: black;
#   border-color: #8b8c8c;
# }
# </style>
# <table id="T_11e6d_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Id</th>
#       <th class="col_heading level0 col1" >SalePrice</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11e6d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_11e6d_row0_col0" class="data row0 col0" >1461</td>
#       <td id="T_11e6d_row0_col1" class="data row0 col1" >121472.379460</td>
#     </tr>
#     <tr>
#       <th id="T_11e6d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_11e6d_row1_col0" class="data row1 col0" >1462</td>
#       <td id="T_11e6d_row1_col1" class="data row1 col1" >160895.374610</td>
#     </tr>
#     <tr>
#       <th id="T_11e6d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_11e6d_row2_col0" class="data row2 col0" >1463</td>
#       <td id="T_11e6d_row2_col1" class="data row2 col1" >178718.339742</td>
#     </tr>
#     <tr>
#       <th id="T_11e6d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_11e6d_row3_col0" class="data row3 col0" >1464</td>
#       <td id="T_11e6d_row3_col1" class="data row3 col1" >181564.773853</td>
#     </tr>
#     <tr>
#       <th id="T_11e6d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_11e6d_row4_col0" class="data row4 col0" >1465</td>
#       <td id="T_11e6d_row4_col1" class="data row4 col1" >197915.357577</td>
#     </tr>
#     <tr>
#       <th id="T_11e6d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_11e6d_row5_col0" class="data row5 col0" >1466</td>
#       <td id="T_11e6d_row5_col1" class="data row5 col1" >170405.406415</td>
#     </tr>
#     <tr>
#       <th id="T_11e6d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_11e6d_row6_col0" class="data row6 col0" >1467</td>
#       <td id="T_11e6d_row6_col1" class="data row6 col1" >161750.826655</td>
#     </tr>
#     <tr>
#       <th id="T_11e6d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_11e6d_row7_col0" class="data row7 col0" >1468</td>
#       <td id="T_11e6d_row7_col1" class="data row7 col1" >151377.919466</td>
#     </tr>
#     <tr>
#       <th id="T_11e6d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_11e6d_row8_col0" class="data row8 col0" >1469</td>
#       <td id="T_11e6d_row8_col1" class="data row8 col1" >187160.807466</td>
#     </tr>
#     <tr>
#       <th id="T_11e6d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_11e6d_row9_col0" class="data row9 col0" >1470</td>
#       <td id="T_11e6d_row9_col1" class="data row9 col1" >129846.818449</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <center> <a href="#top" role="button" aria-pressed="true" >⬆️Back to Table of Contents ⬆️</a>

# %% [markdown]
# <a id="6"></a>
# # <p style="padding:10px;background-color:#0D1C5A;margin:0;color:#F1F40D;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500"> Author Message</p>

# %% [markdown]
# <center> <img src="https://raw.githubusercontent.com/ntclai/PictureForMyProject/main/Untitled.png" style='width: 200px; height: 100px;'>

# %% [markdown]
# <div style="border-radius:10px;border:#034914 solid;padding: 15px;background-color:aliceblue;font-size:90%;text-align:left">
#
# <h4><b>Author :</b> Nguyen Thi Cam Lai </h4>
#
# <h4> <b>Some information:</b> </h4>
#
# <b>👉Read more project :</b> https://www.kaggle.com/nguyenthicamlai <br>
# <b>👉Shoot me mails :</b> lainguyen130302@gmail.com<br>
# <b>👉Connect on LinkedIn :</b> https://www.linkedin.com/in/ntclaii/ <br>
# <b>👉Explore Github :</b> https://github.com/ntclai <br>
#
#
# <center> <strong> If you liked this Notebook, please do upvote. </strong>
#
# <center> <strong> If you have any questions, feel free to comment! </strong>
#
# <center> <strong> ✨Best Wishes✨ </strong>

# %% [markdown]
# <center> <img src="https://raw.githubusercontent.com/ntclai/PictureForMyProject/main/87481-of-thanks-letter-text-logo-calligraphy-drawing%20(1).png" style='width: 600px; height: 300px;'>

# %% [markdown]
# <center> <a href="#top" role="button" aria-pressed="true" >⬆️Back to Table of Contents ⬆️</a>
